# %% [markdown]
# # To generate according to expert

# %% [markdown]
# For my validation data, I like to generate 10 rocks for each rock type, each case proposed by geologist.
#
# The code pipeline:
# 1. Loads individual spectra from files
# 2. Predefined list of specified minerals for each rock
# 3. Combines all the spectrums into a numpy array
# 4. Saves each rock's spectra as a separate NPY file
# 5. Prints a summary of the mineral composition for each rock
#
# specified_minerals = ['Quartz', 'Annite', 'Eastonite', 'Phlogopite', 'Muscovite',
#  'Margarite', 'Anorthite', 'Orthoclase', 'Sanidine', 'Albite']

# %%
import numpy as np
import os
from pathlib import Path
import random
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from scipy import stats, interpolate

def read_spectrum(file_path):
    """
    Read spectrum data from a text file
    Returns wavelength and intensity arrays
    """
    try:
        wavelength, intensity = [], []
        with open(file_path, 'r') as file:
            for line in file:
                try:
                    w, i = map(float, line.strip().split(','))
                    wavelength.append(w)
                    intensity.append(i)
                except ValueError:
                    continue
        return np.array(wavelength), np.array(intensity)
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return np.array([]), np.array([])

def interpolate_spectrum(wavelength, intensity, common_wavelengths):
    """Interpolate spectrum to common wavelength points."""
    if len(wavelength) < 2:  # Need at least 2 points for interpolation
        return None
    try:
        f = interpolate.interp1d(wavelength, intensity, kind='linear',
                                bounds_error=False, fill_value=0)
        return f(common_wavelengths)
    except Exception as e:
        print(f"Error during interpolation: {e}")
        return None

def find_common_wavelength_range(spectra_dict):
    """Find common wavelength range and create uniform wavelength points."""
    min_wavelength = float('inf')
    max_wavelength = float('-inf')
    
    # Find the overall min and max wavelengths
    for wavelengths, _ in spectra_dict:
        if len(wavelengths) > 0:
            min_wavelength = min(min_wavelength, np.min(wavelengths))
            max_wavelength = max(max_wavelength, np.max(wavelengths))
    
    if min_wavelength == float('inf') or max_wavelength == float('-inf'):
        return None
    
    # Create uniform wavelength points
    num_points = 1000  # Fixed number of points
    return np.linspace(min_wavelength, max_wavelength, num_points)

def generate_synthetic_sample_pca(real_data, n_samples=1, min_components=2):
    """Generate synthetic samples using PCA-based method"""
    n_samples_real, n_features = real_data.shape
    n_components = min(n_samples_real - 1, 10)
    n_components = max(n_components, min_components)
    
    scaler = StandardScaler()
    data_scaled = scaler.fit_transform(real_data)
    
    pca = PCA(n_components=n_components)
    data_pca = pca.fit_transform(data_scaled)
    
    synthetic_samples_pca = []
    for dim in range(n_components):
        kde = stats.gaussian_kde(data_pca[:, dim])
        synthetic_samples_pca.append(kde.resample(n_samples)[0])
    
    synthetic_samples_pca = np.array(synthetic_samples_pca).T
    synthetic_samples_scaled = pca.inverse_transform(synthetic_samples_pca)
    synthetic_samples = scaler.inverse_transform(synthetic_samples_scaled)
    synthetic_samples = np.maximum(synthetic_samples, 0)
    
    return synthetic_samples

def generate_synthetic_sample_small(real_data, n_samples=1):
    """Generate synthetic samples for small datasets"""
    synthetic_samples = []
    base_sample = real_data[0]
    
    for _ in range(n_samples):
        segment_size = len(base_sample) // 10
        synthetic = np.zeros_like(base_sample)
        
        for i in range(0, len(base_sample), segment_size):
            segment = base_sample[i:i+segment_size]
            noise_scale = 0.05 * np.std(segment) if np.std(segment) > 0 else 0.05 * np.mean(segment)
            synthetic[i:i+segment_size] = segment + np.random.normal(0, noise_scale, len(segment))
        
        synthetic = np.maximum(synthetic, 0)
        synthetic_samples.append(synthetic)
    
    return np.array(synthetic_samples)

def generate_synthetic_samples(real_data, n_samples, min_samples_for_pca=3):
    """Generate synthetic samples using appropriate method"""
    if len(real_data) < min_samples_for_pca:
        return generate_synthetic_sample_small(real_data, n_samples)
    else:
        return generate_synthetic_sample_pca(real_data, n_samples)

def load_and_preprocess_spectra(folder_path, specified_minerals):
    """Load all spectra and prepare for processing"""
    all_spectra = []
    spectra_by_mineral = {mineral: [] for mineral in specified_minerals}
    
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            mineral_name = filename.split('__')[0]
            if mineral_name in specified_minerals:
                wavelength, intensity = read_spectrum(Path(folder_path) / filename)
                if len(wavelength) > 0:
                    all_spectra.append((wavelength, intensity))
                    spectra_by_mineral[mineral_name].append(filename)
    
    # Find common wavelength range
    common_wavelengths = find_common_wavelength_range(all_spectra)
    if common_wavelengths is None:
        raise ValueError("Could not determine common wavelength range")
    
    return common_wavelengths, spectra_by_mineral

def load_mineral_spectrum(filename, folder_path, common_wavelengths, generate_synthetic=True):
    """Load and process a single mineral spectrum"""
    wavelength, intensity = read_spectrum(Path(folder_path) / filename)
    if len(wavelength) == 0:
        return None
    
    interpolated = interpolate_spectrum(wavelength, intensity, common_wavelengths)
    if interpolated is None:
        return None
    
    if generate_synthetic:
        synthetic = generate_synthetic_samples(interpolated.reshape(1, -1), 1)
        return synthetic[0]
    
    return interpolated

def generate_validation_rocks(
    selected_minerals,
    spectra_dir,
    num_rocks=10,
    spectra_per_rock=10,
    specified_mineral_count=8,
    rruff_dir=None,
    output_dir="validation_rocks",
    generate_synthetic=True
):
    """Generate synthetic validation rocks"""
    if rruff_dir is None:
        rruff_dir = spectra_dir
        
    Path(output_dir).mkdir(exist_ok=True)
    
    # Load and preprocess all spectra
    print("Loading and preprocessing spectra...")
    all_minerals = list(set([mineral for sequence in selected_minerals.values() for mineral in sequence]))
    common_wavelengths, spectra_by_mineral = load_and_preprocess_spectra(spectra_dir, all_minerals)
 
    # Verify available spectra
    for mineral, spectra in spectra_by_mineral.items():
        if not spectra:
            print(f"Warning: No spectra found for {mineral}")
    
    for rock_idx, minerals in selected_minerals.items():
        rock_spectra = []
        mineral_composition = []
        spectrum_files = []  # Store filenames for reference
        
        # Add specified mineral spectra
        # selected_minerals = random.choices(specified_minerals, k=specified_mineral_count)
        for mineral in minerals:
            if spectra_by_mineral[mineral]:
                spectrum_file = random.choice(spectra_by_mineral[mineral])
                spectrum = load_mineral_spectrum(
                    spectrum_file,
                    spectra_dir,
                    common_wavelengths,
                    generate_synthetic=generate_synthetic
                )
                
                if spectrum is not None:
                    rock_spectra.append(spectrum)
                    mineral_composition.append(mineral)
                    spectrum_files.append(spectrum_file)
        
        # Add RRUFF spectra
        rruff_files = [f for f in os.listdir(rruff_dir) if f.endswith('.txt')]
        rruff_count = spectra_per_rock - len(rock_spectra)
        
        for _ in range(rruff_count):
            spectrum_file = random.choice(rruff_files)
            mineral_name = spectrum_file.split('__')[0]
            
            spectrum = load_mineral_spectrum(
                spectrum_file,
                rruff_dir,
                common_wavelengths,
                generate_synthetic=generate_synthetic
            )
            
            if spectrum is not None:
                rock_spectra.append(spectrum)
                mineral_composition.append(f"RRUFF_{mineral_name}")
                spectrum_files.append(spectrum_file)
        
        if rock_spectra:
            # Save spectra data
            rock_spectra_array = np.array(rock_spectra)
            output_base = Path(output_dir) / f"rock_{rock_idx+1:02d}"
            np.save(f"{output_base}_wavelengths.npy", common_wavelengths)
            np.save(f"{output_base}_intensities.npy", rock_spectra_array)
            
            # Save composition row by row, matching the order in the intensities array
            with open(f"{output_base}_composition.txt", 'w') as f:
                # Write header
                f.write("Row\tMineral\tFilename\n")
                # Write each row's information
                for idx, (mineral, filename) in enumerate(zip(mineral_composition, spectrum_files)):
                    f.write(f"{idx}\t{mineral}\t{filename}\n")
            
            # Print summary
            print(f"\nRock {rock_idx+1} Composition:")
            print("-" * 50)
            print("Row\tMineral\tFilename")
            print("-" * 50)
            for idx, (mineral, filename) in enumerate(zip(mineral_composition, spectrum_files)):
                print(f"{idx}\t{mineral}\t{filename}")
            print("-" * 50)
            
            # Also print mineral counts for overview
            print("\nMineral Counts:")
            for mineral in sorted(set(mineral_composition)):
                count = mineral_composition.count(mineral)
                print(f"{mineral}: {count} spectra")
        else:
            print(f"\nWarning: Could not generate Rock {rock_idx+1} - no valid spectra")

# %%
if __name__ == "__main__":

    # refer to rock-samples.csv
    selected_minerals = {
        # Group 1: Granite (0-9)
        0: ['Albite', 'Anorthite', 'Quartz', 'Quartz', 'Annite', 'Muscovite', 'Quartz', 'Albite', 'Annite', 'Orthoclase'],
        1: ['Albite', 'Quartz', 'Annite', 'Annite', 'Muscovite', 'Orthoclase', 'Orthoclase', 'Quartz', 'Quartz', 'Anorthite'],
        2: ['Margarite', 'Quartz', 'Quartz', 'Margarite', 'Orthoclase', 'Margarite', 'Anorthite', 'Quartz', 'Annite', 'Quartz'],
        3: ['Orthoclase', 'Muscovite', 'Annite', 'Orthoclase', 'Albite', 'Anorthite', 'Muscovite', 'Annite', 'Quartz', 'Phlogopite'],
        4: ['Annite', 'Phlogopite', 'Sanidine', 'Albite', 'Sanidine', 'Quartz', 'Annite', 'Sanidine', 'Sanidine', 'Sanidine'],
        5: ['Annite', 'Quartz', 'Quartz', 'Annite', 'Albite', 'Anorthite', 'Orthoclase', 'Albite', 'Annite', 'Muscovite'],
        6: ['Quartz', 'Annite', 'Muscovite', 'Quartz', 'Anorthite', 'Orthoclase', 'Quartz', 'Albite', 'Quartz', 'Annite'],
        7: ['Orthoclase', 'Eastonite', 'Anorthite', 'Albite', 'Eastonite', 'Phlogopite', 'Quartz', 'Quartz', 'Eastonite', 'Eastonite'],
        8: ['Anorthite', 'Quartz', 'Staurolite', 'Garnet', 'Orthoclase', 'Phlogopite', 'Muscovite', 'Albite', 'Quartz', 'Annite'],
        9: ['Garnet', 'Annite', 'Quartz', 'Anorthite', 'Albite', 'Orthoclase', 'Muscovite', 'Garnet', 'Quartz', 'Annite'],

        # Group 2: Sandstone (10-19)
        10: ['Quartz', 'Calcite', 'Orthoclase', 'Albite', 'Anorthite', 'Pyrite', 'Annite', 'Phlogopite', 'Muscovite', 'Tourmaline'],
        11: ['Albite', 'Orthoclase', 'Anorthite', 'Tourmaline', 'Rutile', 'Muscovite', 'Quartz', 'Calcite', 'Annite', 'Anorthite'],
        12: ['Sanidine', 'Albite', 'Sanidine', 'Quartz', 'Calcite', 'Quartz', 'Albite', 'Anorthite', 'Margarite', 'Annite'],
        13: ['Pyrite', 'Orthoclase', 'Quartz', 'Calcite', 'Quartz', 'Albite', 'Anorthite', 'Tourmaline', 'Rutile', 'Annite'],
        14: ['Albite', 'Anorthite', 'Anorthite', 'Phlogopite', 'Muscovite', 'Annite', 'Quartz', 'Orthoclase', 'Quartz', 'Quartz'],
        15: ['Orthoclase', 'Albite', 'Anorthite', 'Annite', 'Muscovite', 'Quartz', 'Quartz', 'Quartz', 'Tourmaline', 'Annite'],
        16: ['Quartz', 'Anorthite', 'Orthoclase', 'Orthoclase', 'Phlogopite', 'Epidote', 'Quartz', 'Omphacite', 'Quartz', 'Annite'],
        17: ['Albite', 'Phlogopite', 'Orthoclase', 'Albite', 'Muscovite', 'Annite', 'Calcite', 'Quartz', 'Albite', 'Pyrite'],
        18: ['Eastonite', 'Albite', 'Quartz', 'Quartz', 'Albite', 'Eastonite', 'Muscovite', 'Quartz', 'Calcite', 'Annite'],
        19: ['Quartz', 'Muscovite', 'Tourmaline', 'Quartz', 'Calcite', 'Albite', 'Tourmaline', 'Annite', 'Muscovite', 'Orthoclase'],

        # Group 3: Limestone (20-29)
        20: ['Calcite', 'Quartz', 'Calcite', 'Calcite', 'Calcite', 'Anorthite', 'Albite', 'Calcite', 'Calcite', 'Calcite'],
        21: ['Andalusite', 'Calcite', 'Calcite', 'Albite', 'Orthoclase', 'Calcite', 'Calcite', 'Kyanite', 'Pyrite', 'Calcite'],
        22: ['Quartz', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Quartz', 'Calcite', 'Calcite'],
        23: ['Dolomite', 'Calcite', 'Calcite', 'Epidote', 'Rhodochrosite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite'],
        24: ['Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite'],
        25: ['Quartz', 'Calcite', 'Quartz', 'Albite', 'Calcite', 'Pyrite', 'Quartz', 'Calcite', 'Calcite', 'Calcite'],
        26: ['Calcite', 'Quartz', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Quartz', 'Calcite', 'Quartz'],
        27: ['Sanidine', 'Quartz', 'Sanidine', 'Calcite', 'Calcite', 'Sanidine', 'Calcite', 'Calcite', 'Calcite', 'Calcite'],
        28: ['Calcite', 'Calcite', 'Calcite', 'Albite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite'],
        29: ['Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite']
            
    }
    
    generate_validation_rocks(
        selected_minerals,
        spectra_dir="/home/iyeszin/Desktop/my git/minerals-rocks-relationship/all about rruff/excellent_unoriented",
        num_rocks=1,
        spectra_per_rock=10,
        specified_mineral_count=10,
        rruff_dir="/home/iyeszin/Desktop/my git/minerals-rocks-relationship/all about rruff/excellent_unoriented",
        output_dir="validation_rocks",
        generate_synthetic=True
    )
# Out:
# Loading and preprocessing spectra...
# Warning: No spectra found for Garnet
#
# Rock 1 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Albite	Albite__R040068__Raman__532__0__unoriented__Raman_Data_Processed__15181.txt
# 1	Anorthite	Anorthite__R060193__Raman__532__0__unoriented__Raman_Data_Processed__33260.txt
# 2	Quartz	Quartz__R150074__Raman__780__0__unoriented__Raman_Data_Processed__38603.txt
# 3	Quartz	Quartz__R110108__Raman__780__0__unoriented__Raman_Data_Processed__36253.txt
# 4	Annite	Annite__R060211__Raman__532__0__unoriented__Raman_Data_Processed__39791.txt
# 5	Muscovite	Muscovite__R050198__Raman__532__0__unoriented__Raman_Data_Processed__30430.txt
# 6	Quartz	Quartz__X080015__Raman__532__0__unoriented__Raman_Data_Processed__31562.txt
# 7	Albite	Albite__R060054__Raman__780__0__unoriented__Raman_Data_Processed__29474.txt
# 8	Annite	Annite__R060211__Raman__532__0__unoriented__Raman_Data_Processed__39791.txt
# 9	Orthoclase	Orthoclase__R050367__Raman__532__0__unoriented__Raman_Data_Processed__29607.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 2 spectra
# Annite: 2 spectra
# Anorthite: 1 spectra
# Muscovite: 1 spectra
# Orthoclase: 1 spectra
# Quartz: 3 spectra
#
# Rock 2 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Albite	Albite__R040068__Raman__532__0__unoriented__Raman_Data_Processed__15181.txt
# 1	Quartz	Quartz__R050125__Raman__514__0__unoriented__Raman_Data_Processed__10122.txt
# 2	Annite	Annite__R060211__Raman__532__0__unoriented__Raman_Data_Processed__39791.txt
# 3	Annite	Annite__R060211__Raman__532__0__unoriented__Raman_Data_Processed__39791.txt
# 4	Muscovite	Muscovite__R050080__Raman__514__0__unoriented__Raman_Data_Processed__10046.txt
# 5	Orthoclase	Orthoclase__R050367__Raman__532__0__unoriented__Raman_Data_Processed__29607.txt
# 6	Orthoclase	Orthoclase__R050185__Raman__514__0__unoriented__Raman_Data_Processed__10206.txt
# 7	Quartz	Quartz__X080015__Raman__780__0__unoriented__Raman_Data_Processed__31560.txt
# 8	Quartz	Quartz__R050125__Raman__532__0__unoriented__Raman_Data_Processed__31947.txt
# 9	Anorthite	Anorthite__R050104__Raman__780__0__unoriented__Raman_Data_Processed__27005.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Annite: 2 spectra
# Anorthite: 1 spectra
# Muscovite: 1 spectra
# Orthoclase: 2 spectra
# Quartz: 3 spectra
#
# Rock 3 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Margarite	Margarite__R060839__Raman__785__0__unoriented__Raman_Data_Processed__16830.txt
# 1	Quartz	Quartz__X080016__Raman__780__0__unoriented__Raman_Data_Processed__31558.txt
# 2	Quartz	Quartz__X080016__Raman__780__0__unoriented__Raman_Data_Processed__31558.txt
# 3	Margarite	Margarite__R060839__Raman__532__0__unoriented__Raman_Data_Processed__12927.txt
# 4	Orthoclase	Orthoclase__R150014__Raman__780__0__unoriented__Raman_Data_Processed__39208.txt
# 5	Margarite	Margarite__R060839__Raman__785__0__unoriented__Raman_Data_Processed__16830.txt
# 6	Anorthite	Anorthite__R050104__Raman__780__0__unoriented__Raman_Data_Processed__27005.txt
# 7	Quartz	Quartz__X080016__Raman__780__0__unoriented__Raman_Data_Processed__31558.txt
# 8	Annite	Annite__R060211__Raman__532__0__unoriented__Raman_Data_Processed__39791.txt
# 9	Quartz	Quartz__R050125__Raman__780__0__unoriented__Raman_Data_Processed__31945.txt
# --------------------------------------------------
#
# Mineral Counts:
# Annite: 1 spectra
# Anorthite: 1 spectra
# Margarite: 3 spectra
# Orthoclase: 1 spectra
# Quartz: 4 spectra
#
# Rock 4 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Orthoclase	Orthoclase__R070001__Raman__785__0__unoriented__Raman_Data_Processed__29485.txt
# 1	Muscovite	Muscovite__R050188__Raman__532__0__unoriented__Raman_Data_Processed__30077.txt
# 2	Annite	Annite__R060211__Raman__532__0__unoriented__Raman_Data_Processed__39791.txt
# 3	Orthoclase	Orthoclase__R050185__Raman__514__0__unoriented__Raman_Data_Processed__10206.txt
# 4	Albite	Albite__R050402__Raman__514__0__unoriented__Raman_Data_Processed__10859.txt
# 5	Anorthite	Anorthite__R040059__Raman__780__0__unoriented__Raman_Data_Processed__26651.txt
# 6	Muscovite	Muscovite__R040104__Raman__532__0__unoriented__Raman_Data_Processed__30000.txt
# 7	Annite	Annite__R060204__Raman__780__0__unoriented__Raman_Data_Processed__33304.txt
# 8	Quartz	Quartz__R060604__Raman__780__0__unoriented__Raman_Data_Processed__31951.txt
# 9	Phlogopite	Phlogopite__R070330__Raman__785__0__unoriented__Raman_Data_Processed__20673.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Annite: 2 spectra
# Anorthite: 1 spectra
# Muscovite: 2 spectra
# Orthoclase: 2 spectra
# Phlogopite: 1 spectra
# Quartz: 1 spectra
#
# Rock 5 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Annite	Annite__R060211__Raman__532__0__unoriented__Raman_Data_Processed__39791.txt
# 1	Phlogopite	Phlogopite__R050068__Raman__514__0__unoriented__Raman_Data_Processed__9975.txt
# 2	Sanidine	Sanidine__R060313__Raman__780__0__unoriented__Raman_Data_Processed__34075.txt
# 3	Albite	Albite__R070268__Raman__532__0__unoriented__Raman_Data_Processed__20224.txt
# 4	Sanidine	Sanidine__R060313__Raman__532__0__unoriented__Raman_Data_Processed__34073.txt
# 5	Quartz	Quartz__R040031__Raman__514__0__unoriented__Raman_Data_Processed__9312.txt
# 6	Annite	Annite__R060204__Raman__780__0__unoriented__Raman_Data_Processed__33304.txt
# 7	Sanidine	Sanidine__R060313__Raman__532__0__unoriented__Raman_Data_Processed__34073.txt
# 8	Sanidine	Sanidine__R060313__Raman__532__0__unoriented__Raman_Data_Processed__34073.txt
# 9	Sanidine	Sanidine__R060313__Raman__780__0__unoriented__Raman_Data_Processed__34075.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Annite: 2 spectra
# Phlogopite: 1 spectra
# Quartz: 1 spectra
# Sanidine: 5 spectra
#
# Rock 6 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Annite	Annite__R060204__Raman__780__0__unoriented__Raman_Data_Processed__33304.txt
# 1	Quartz	Quartz__R040031__Raman__780__0__unoriented__Raman_Data_Processed__26341.txt
# 2	Quartz	Quartz__R050125__Raman__532__0__unoriented__Raman_Data_Processed__31947.txt
# 3	Annite	Annite__R060204__Raman__532__0__unoriented__Raman_Data_Processed__33302.txt
# 4	Albite	Albite__R040068__Raman__532__0__unoriented__Raman_Data_Processed__15181.txt
# 5	Anorthite	Anorthite__R070598__Raman__780__0__unoriented__Raman_Data_Processed__23148.txt
# 6	Orthoclase	Orthoclase__R060077__Raman__780__0__unoriented__Raman_Data_Processed__27548.txt
# 7	Albite	Albite__R070268__Raman__785__0__unoriented__Raman_Data_Processed__25732.txt
# 8	Annite	Annite__R060204__Raman__780__0__unoriented__Raman_Data_Processed__33304.txt
# 9	Muscovite	Muscovite__R040108__Raman__532__0__unoriented__Raman_Data_Processed__30003.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 2 spectra
# Annite: 3 spectra
# Anorthite: 1 spectra
# Muscovite: 1 spectra
# Orthoclase: 1 spectra
# Quartz: 2 spectra
#
# Rock 7 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Quartz	Quartz__R040031__Raman__780__0__unoriented__Raman_Data_Processed__26341.txt
# 1	Annite	Annite__R060204__Raman__532__0__unoriented__Raman_Data_Processed__33302.txt
# 2	Muscovite	Muscovite__R050198__Raman__532__0__unoriented__Raman_Data_Processed__30430.txt
# 3	Quartz	Quartz__R150074__Raman__532__0__unoriented__Raman_Data_Processed__38601.txt
# 4	Anorthite	Anorthite__R060193__Raman__532__0__unoriented__Raman_Data_Processed__33260.txt
# 5	Orthoclase	Orthoclase__R050367__Raman__532__0__unoriented__Raman_Data_Processed__29607.txt
# 6	Quartz	Quartz__X080016__Raman__780__0__unoriented__Raman_Data_Processed__31558.txt
# 7	Albite	Albite__R040129__Raman__532__0__unoriented__Raman_Data_Processed__19752.txt
# 8	Quartz	Quartz__R110108__Raman__780__0__unoriented__Raman_Data_Processed__36253.txt
# 9	Annite	Annite__R060204__Raman__780__0__unoriented__Raman_Data_Processed__33304.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Annite: 2 spectra
# Anorthite: 1 spectra
# Muscovite: 1 spectra
# Orthoclase: 1 spectra
# Quartz: 4 spectra
#
# Rock 8 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Orthoclase	Orthoclase__R050185__Raman__532__0__unoriented__Raman_Data_Processed__28159.txt
# 1	Eastonite	Eastonite__R100078__Raman__780__0__unoriented__Raman_Data_Processed__34224.txt
# 2	Anorthite	Anorthite__R040059__Raman__532__0__unoriented__Raman_Data_Processed__26655.txt
# 3	Albite	Albite__R070268__Raman__785__0__unoriented__Raman_Data_Processed__25732.txt
# 4	Eastonite	Eastonite__R100078__Raman__780__0__unoriented__Raman_Data_Processed__34224.txt
# 5	Phlogopite	Phlogopite__R050068__Raman__785__0__unoriented__Raman_Data_Processed__21254.txt
# 6	Quartz	Quartz__X080015__Raman__532__0__unoriented__Raman_Data_Processed__31562.txt
# 7	Quartz	Quartz__R040031__Raman__780__0__unoriented__Raman_Data_Processed__26341.txt
# 8	Eastonite	Eastonite__R100078__Raman__780__0__unoriented__Raman_Data_Processed__34224.txt
# 9	Eastonite	Eastonite__R100078__Raman__780__0__unoriented__Raman_Data_Processed__34224.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Anorthite: 1 spectra
# Eastonite: 4 spectra
# Orthoclase: 1 spectra
# Phlogopite: 1 spectra
# Quartz: 2 spectra
#
# Rock 9 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Anorthite	Anorthite__R060193__Raman__780__0__unoriented__Raman_Data_Processed__33263.txt
# 1	Quartz	Quartz__R110108__Raman__532__0__unoriented__Raman_Data_Processed__36255.txt
# 2	Staurolite	Staurolite__R080120__Raman__532__0__unoriented__Raman_Data_Processed__30485.txt
# 3	Orthoclase	Orthoclase__R060077__Raman__532__0__unoriented__Raman_Data_Processed__27546.txt
# 4	Phlogopite	Phlogopite__R050068__Raman__532__0__unoriented__Raman_Data_Processed__21256.txt
# 5	Muscovite	Muscovite__R100147__Raman__780__0__unoriented__Raman_Data_Processed__34574.txt
# 6	Albite	Albite__R050402__Raman__532__0__unoriented__Raman_Data_Processed__30006.txt
# 7	Quartz	Quartz__R100134__Raman__780__0__unoriented__Raman_Data_Processed__34504.txt
# 8	Annite	Annite__R060204__Raman__532__0__unoriented__Raman_Data_Processed__33302.txt
# 9	RRUFF_Brannerite	Brannerite__R080091__Raman__532__0__unoriented__Raman_Data_Processed__29923.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Annite: 1 spectra
# Anorthite: 1 spectra
# Muscovite: 1 spectra
# Orthoclase: 1 spectra
# Phlogopite: 1 spectra
# Quartz: 2 spectra
# RRUFF_Brannerite: 1 spectra
# Staurolite: 1 spectra
#
# Rock 10 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Annite	Annite__R060211__Raman__532__0__unoriented__Raman_Data_Processed__39791.txt
# 1	Quartz	Quartz__R100134__Raman__532__0__unoriented__Raman_Data_Processed__34502.txt
# 2	Anorthite	Anorthite__R050104__Raman__780__0__unoriented__Raman_Data_Processed__27005.txt
# 3	Albite	Albite__R050253__Raman__532__0__unoriented__Raman_Data_Processed__28172.txt
# 4	Orthoclase	Orthoclase__R040055__Raman__532__0__unoriented__Raman_Data_Processed__15131.txt
# 5	Muscovite	Muscovite__R100147__Raman__532__0__unoriented__Raman_Data_Processed__34576.txt
# 6	Quartz	Quartz__R150074__Raman__532__0__unoriented__Raman_Data_Processed__38601.txt
# 7	Annite	Annite__R060211__Raman__532__0__unoriented__Raman_Data_Processed__39791.txt
# 8	RRUFF_Ferrosilite	Ferrosilite__R070386__Raman__532__0__unoriented__Raman_Data_Processed__22223.txt
# 9	RRUFF_Sphalerite	Sphalerite__R040136__Raman__785__0__unoriented__Raman_Data_Processed__2779.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Annite: 2 spectra
# Anorthite: 1 spectra
# Muscovite: 1 spectra
# Orthoclase: 1 spectra
# Quartz: 2 spectra
# RRUFF_Ferrosilite: 1 spectra
# RRUFF_Sphalerite: 1 spectra
#
# Rock 11 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Quartz	Quartz__R150074__Raman__780__0__unoriented__Raman_Data_Processed__38603.txt
# 1	Calcite	Calcite__R050307__Raman__514__0__unoriented__Raman_Data_Processed__10750.txt
# 2	Orthoclase	Orthoclase__R050367__Raman__532__0__unoriented__Raman_Data_Processed__29607.txt
# 3	Albite	Albite__R040068__Raman__785__0__unoriented__Raman_Data_Processed__15183.txt
# 4	Anorthite	Anorthite__R060193__Raman__532__0__unoriented__Raman_Data_Processed__33260.txt
# 5	Pyrite	Pyrite__R050190__Raman__514__0__unoriented__Raman_Data_Processed__10917.txt
# 6	Annite	Annite__R060204__Raman__532__0__unoriented__Raman_Data_Processed__33302.txt
# 7	Phlogopite	Phlogopite__R050068__Raman__532__0__unoriented__Raman_Data_Processed__21256.txt
# 8	Muscovite	Muscovite__R040124__Raman__514__0__unoriented__Raman_Data_Processed__30222.txt
# 9	Tourmaline	Tourmaline__R110133__Raman__780__0__unoriented__Raman_Data_Processed__35662.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Annite: 1 spectra
# Anorthite: 1 spectra
# Calcite: 1 spectra
# Muscovite: 1 spectra
# Orthoclase: 1 spectra
# Phlogopite: 1 spectra
# Pyrite: 1 spectra
# Quartz: 1 spectra
# Tourmaline: 1 spectra
#
# Rock 12 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Albite	Albite__R040068__Raman__514__0__unoriented__Raman_Data_Processed__9427.txt
# 1	Orthoclase	Orthoclase__R150014__Raman__780__0__unoriented__Raman_Data_Processed__39208.txt
# 2	Anorthite	Anorthite__R050104__Raman__532__0__unoriented__Raman_Data_Processed__27007.txt
# 3	Tourmaline	Tourmaline__R070563__Raman__532__0__unoriented__Raman_Data_Processed__31476.txt
# 4	Rutile	Rutile__R060493__Raman__532__0__unoriented__Raman_Data_Processed__10258.txt
# 5	Muscovite	Muscovite__R050188__Raman__532__0__unoriented__Raman_Data_Processed__30077.txt
# 6	Quartz	Quartz__R050125__Raman__780__0__unoriented__Raman_Data_Processed__31945.txt
# 7	Calcite	Calcite__R050128__Raman__514__0__unoriented__Raman_Data_Processed__5646.txt
# 8	Annite	Annite__R060204__Raman__532__0__unoriented__Raman_Data_Processed__33302.txt
# 9	Anorthite	Anorthite__R100170__Raman__532__0__unoriented__Raman_Data_Processed__34703.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Annite: 1 spectra
# Anorthite: 2 spectra
# Calcite: 1 spectra
# Muscovite: 1 spectra
# Orthoclase: 1 spectra
# Quartz: 1 spectra
# Rutile: 1 spectra
# Tourmaline: 1 spectra
#
# Rock 13 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Sanidine	Sanidine__R060313__Raman__780__0__unoriented__Raman_Data_Processed__34075.txt
# 1	Albite	Albite__R060054__Raman__532__0__unoriented__Raman_Data_Processed__26970.txt
# 2	Sanidine	Sanidine__R060313__Raman__532__0__unoriented__Raman_Data_Processed__34073.txt
# 3	Quartz	Quartz__R060604__Raman__780__0__unoriented__Raman_Data_Processed__31951.txt
# 4	Calcite	Calcite__R050009__Raman__514__0__unoriented__Raman_Data_Processed__9847.txt
# 5	Quartz	Quartz__R040031__Raman__514__0__unoriented__Raman_Data_Processed__9312.txt
# 6	Albite	Albite__R050253__Raman__780__0__unoriented__Raman_Data_Processed__28174.txt
# 7	Anorthite	Anorthite__R060275__Raman__532__0__unoriented__Raman_Data_Processed__33994.txt
# 8	Margarite	Margarite__R060839__Raman__785__0__unoriented__Raman_Data_Processed__16830.txt
# 9	Annite	Annite__R060211__Raman__532__0__unoriented__Raman_Data_Processed__39791.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 2 spectra
# Annite: 1 spectra
# Anorthite: 1 spectra
# Calcite: 1 spectra
# Margarite: 1 spectra
# Quartz: 2 spectra
# Sanidine: 2 spectra
#
# Rock 14 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Pyrite	Pyrite__R050190__Raman__514__0__unoriented__Raman_Data_Processed__10917.txt
# 1	Orthoclase	Orthoclase__R040055__Raman__785__0__unoriented__Raman_Data_Processed__15129.txt
# 2	Quartz	Quartz__R110108__Raman__532__0__unoriented__Raman_Data_Processed__36255.txt
# 3	Calcite	Calcite__R040070__Raman__532__0__unoriented__Raman_Data_Processed__15330.txt
# 4	Quartz	Quartz__R150091__Raman__532__0__unoriented__Raman_Data_Processed__39166.txt
# 5	Albite	Albite__R040068__Raman__514__0__unoriented__Raman_Data_Processed__9427.txt
# 6	Anorthite	Anorthite__R060221__Raman__532__0__unoriented__Raman_Data_Processed__33379.txt
# 7	Tourmaline	Tourmaline__R060123__Raman__532__0__unoriented__Raman_Data_Processed__31953.txt
# 8	Rutile	Rutile__R060493__Raman__532__0__unoriented__Raman_Data_Processed__10258.txt
# 9	Annite	Annite__R060204__Raman__532__0__unoriented__Raman_Data_Processed__33302.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Annite: 1 spectra
# Anorthite: 1 spectra
# Calcite: 1 spectra
# Orthoclase: 1 spectra
# Pyrite: 1 spectra
# Quartz: 2 spectra
# Rutile: 1 spectra
# Tourmaline: 1 spectra
#
# Rock 15 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Albite	Albite__R050402__Raman__514__0__unoriented__Raman_Data_Processed__10859.txt
# 1	Anorthite	Anorthite__R060082__Raman__532__0__unoriented__Raman_Data_Processed__27582.txt
# 2	Anorthite	Anorthite__R100170__Raman__532__0__unoriented__Raman_Data_Processed__34703.txt
# 3	Phlogopite	Phlogopite__R070330__Raman__532__0__unoriented__Raman_Data_Processed__20671.txt
# 4	Muscovite	Muscovite__R040104__Raman__532__0__unoriented__Raman_Data_Processed__30000.txt
# 5	Annite	Annite__R060211__Raman__532__0__unoriented__Raman_Data_Processed__39791.txt
# 6	Quartz	Quartz__R150074__Raman__532__0__unoriented__Raman_Data_Processed__38601.txt
# 7	Orthoclase	Orthoclase__R150014__Raman__780__0__unoriented__Raman_Data_Processed__39208.txt
# 8	Quartz	Quartz__X080015__Raman__780__0__unoriented__Raman_Data_Processed__31560.txt
# 9	Quartz	Quartz__R060604__Raman__532__0__unoriented__Raman_Data_Processed__31949.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Annite: 1 spectra
# Anorthite: 2 spectra
# Muscovite: 1 spectra
# Orthoclase: 1 spectra
# Phlogopite: 1 spectra
# Quartz: 3 spectra
#
# Rock 16 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Orthoclase	Orthoclase__R040055__Raman__532__0__unoriented__Raman_Data_Processed__15131.txt
# 1	Albite	Albite__R050253__Raman__514__0__unoriented__Raman_Data_Processed__10664.txt
# 2	Anorthite	Anorthite__R070598__Raman__532__0__unoriented__Raman_Data_Processed__23146.txt
# 3	Annite	Annite__R060204__Raman__780__0__unoriented__Raman_Data_Processed__33304.txt
# 4	Muscovite	Muscovite__R060182__Raman__532__0__unoriented__Raman_Data_Processed__33204.txt
# 5	Quartz	Quartz__R050125__Raman__514__0__unoriented__Raman_Data_Processed__10122.txt
# 6	Quartz	Quartz__R150074__Raman__532__0__unoriented__Raman_Data_Processed__38601.txt
# 7	Quartz	Quartz__R110108__Raman__532__0__unoriented__Raman_Data_Processed__36255.txt
# 8	Tourmaline	Tourmaline__R110131__Raman__532__0__unoriented__Raman_Data_Processed__35656.txt
# 9	Annite	Annite__R060211__Raman__532__0__unoriented__Raman_Data_Processed__39791.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Annite: 2 spectra
# Anorthite: 1 spectra
# Muscovite: 1 spectra
# Orthoclase: 1 spectra
# Quartz: 3 spectra
# Tourmaline: 1 spectra
#
# Rock 17 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Quartz	Quartz__R040031__Raman__532__0__unoriented__Raman_Data_Processed__26343.txt
# 1	Anorthite	Anorthite__R100170__Raman__532__0__unoriented__Raman_Data_Processed__34703.txt
# 2	Orthoclase	Orthoclase__R050185__Raman__514__0__unoriented__Raman_Data_Processed__10206.txt
# 3	Orthoclase	Orthoclase__R040055__Raman__785__0__unoriented__Raman_Data_Processed__15129.txt
# 4	Phlogopite	Phlogopite__R050068__Raman__785__0__unoriented__Raman_Data_Processed__21254.txt
# 5	Epidote	Epidote__R050191__Raman__780__0__unoriented__Raman_Data_Processed__27802.txt
# 6	Quartz	Quartz__R110104__Raman__780__0__unoriented__Raman_Data_Processed__35857.txt
# 7	Omphacite	Omphacite__R061129__Raman__532__0__unoriented__Raman_Data_Processed__16700.txt
# 8	Quartz	Quartz__X080016__Raman__780__0__unoriented__Raman_Data_Processed__31558.txt
# 9	Annite	Annite__R060204__Raman__532__0__unoriented__Raman_Data_Processed__33302.txt
# --------------------------------------------------
#
# Mineral Counts:
# Annite: 1 spectra
# Anorthite: 1 spectra
# Epidote: 1 spectra
# Omphacite: 1 spectra
# Orthoclase: 2 spectra
# Phlogopite: 1 spectra
# Quartz: 3 spectra
#
# Rock 18 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Albite	Albite__R100169__Raman__532__0__unoriented__Raman_Data_Processed__34686.txt
# 1	Phlogopite	Phlogopite__R050068__Raman__532__0__unoriented__Raman_Data_Processed__21256.txt
# 2	Orthoclase	Orthoclase__R070001__Raman__785__0__unoriented__Raman_Data_Processed__29485.txt
# 3	Albite	Albite__R060054__Raman__780__0__unoriented__Raman_Data_Processed__29474.txt
# 4	Muscovite	Muscovite__R060182__Raman__532__0__unoriented__Raman_Data_Processed__33204.txt
# 5	Annite	Annite__R060204__Raman__532__0__unoriented__Raman_Data_Processed__33302.txt
# 6	Calcite	Calcite__R040070__Raman__532__0__unoriented__Raman_Data_Processed__15330.txt
# 7	Quartz	Quartz__R040031__Raman__780__0__unoriented__Raman_Data_Processed__26341.txt
# 8	Albite	Albite__R060054__Raman__532__0__unoriented__Raman_Data_Processed__26970.txt
# 9	Pyrite	Pyrite__R080030__Raman__780__0__unoriented__Raman_Data_Processed__26783.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 3 spectra
# Annite: 1 spectra
# Calcite: 1 spectra
# Muscovite: 1 spectra
# Orthoclase: 1 spectra
# Phlogopite: 1 spectra
# Pyrite: 1 spectra
# Quartz: 1 spectra
#
# Rock 19 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Eastonite	Eastonite__R100078__Raman__780__0__unoriented__Raman_Data_Processed__34224.txt
# 1	Albite	Albite__R100169__Raman__780__0__unoriented__Raman_Data_Processed__34688.txt
# 2	Quartz	Quartz__R040031__Raman__780__0__unoriented__Raman_Data_Processed__26341.txt
# 3	Quartz	Quartz__X080015__Raman__780__0__unoriented__Raman_Data_Processed__31560.txt
# 4	Albite	Albite__R100169__Raman__532__0__unoriented__Raman_Data_Processed__34686.txt
# 5	Eastonite	Eastonite__R100078__Raman__780__0__unoriented__Raman_Data_Processed__34224.txt
# 6	Muscovite	Muscovite__R050188__Raman__514__0__unoriented__Raman_Data_Processed__10210.txt
# 7	Quartz	Quartz__R040031__Raman__514__0__unoriented__Raman_Data_Processed__9312.txt
# 8	Calcite	Calcite__R050127__Raman__514__0__unoriented__Raman_Data_Processed__10126.txt
# 9	Annite	Annite__R060204__Raman__780__0__unoriented__Raman_Data_Processed__33304.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 2 spectra
# Annite: 1 spectra
# Calcite: 1 spectra
# Eastonite: 2 spectra
# Muscovite: 1 spectra
# Quartz: 3 spectra
#
# Rock 20 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Quartz	Quartz__R050125__Raman__514__0__unoriented__Raman_Data_Processed__10122.txt
# 1	Muscovite	Muscovite__R050188__Raman__780__0__unoriented__Raman_Data_Processed__30079.txt
# 2	Tourmaline	Tourmaline__R110131__Raman__532__0__unoriented__Raman_Data_Processed__35656.txt
# 3	Quartz	Quartz__R040031__Raman__514__0__unoriented__Raman_Data_Processed__9312.txt
# 4	Calcite	Calcite__R050128__Raman__532__0__unoriented__Raman_Data_Processed__27265.txt
# 5	Albite	Albite__R050402__Raman__532__0__unoriented__Raman_Data_Processed__30006.txt
# 6	Tourmaline	Tourmaline__R110131__Raman__532__0__unoriented__Raman_Data_Processed__35656.txt
# 7	Annite	Annite__R060211__Raman__532__0__unoriented__Raman_Data_Processed__39791.txt
# 8	Muscovite	Muscovite__R061120__Raman__532__0__unoriented__Raman_Data_Processed__16360.txt
# 9	Orthoclase	Orthoclase__R040055__Raman__785__0__unoriented__Raman_Data_Processed__15129.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Annite: 1 spectra
# Calcite: 1 spectra
# Muscovite: 2 spectra
# Orthoclase: 1 spectra
# Quartz: 2 spectra
# Tourmaline: 2 spectra
#
# Rock 21 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Calcite	Calcite__R050127__Raman__532__0__unoriented__Raman_Data_Processed__27194.txt
# 1	Quartz	Quartz__R040031__Raman__514__0__unoriented__Raman_Data_Processed__9312.txt
# 2	Calcite	Calcite__R050128__Raman__514__0__unoriented__Raman_Data_Processed__5646.txt
# 3	Calcite	Calcite__R050130__Raman__780__0__unoriented__Raman_Data_Processed__27275.txt
# 4	Calcite	Calcite__R050009__Raman__785__0__unoriented__Raman_Data_Processed__21025.txt
# 5	Anorthite	Anorthite__R060275__Raman__532__0__unoriented__Raman_Data_Processed__33994.txt
# 6	Albite	Albite__R060054__Raman__532__0__unoriented__Raman_Data_Processed__26970.txt
# 7	Calcite	Calcite__R050009__Raman__785__0__unoriented__Raman_Data_Processed__21025.txt
# 8	Calcite	Calcite__R050130__Raman__514__0__unoriented__Raman_Data_Processed__10130.txt
# 9	Calcite	Calcite__R050307__Raman__514__0__unoriented__Raman_Data_Processed__10750.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Anorthite: 1 spectra
# Calcite: 7 spectra
# Quartz: 1 spectra
#
# Rock 22 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Andalusite	Andalusite__R060197__Raman__780__0__unoriented__Raman_Data_Processed__31821.txt
# 1	Calcite	Calcite__R150075__Raman__780__0__unoriented__Raman_Data_Processed__38607.txt
# 2	Calcite	Calcite__R150075__Raman__532__0__unoriented__Raman_Data_Processed__38605.txt
# 3	Albite	Albite__R050253__Raman__514__0__unoriented__Raman_Data_Processed__10664.txt
# 4	Orthoclase	Orthoclase__R040055__Raman__514__0__unoriented__Raman_Data_Processed__9392.txt
# 5	Calcite	Calcite__R150075__Raman__532__0__unoriented__Raman_Data_Processed__38605.txt
# 6	Calcite	Calcite__R040070__Raman__532__0__unoriented__Raman_Data_Processed__15330.txt
# 7	Kyanite	Kyanite__R100139__Raman__532__0__unoriented__Raman_Data_Processed__34737.txt
# 8	Pyrite	Pyrite__R100166__Raman__532__0__unoriented__Raman_Data_Processed__34671.txt
# 9	Calcite	Calcite__R050009__Raman__785__0__unoriented__Raman_Data_Processed__21025.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Andalusite: 1 spectra
# Calcite: 5 spectra
# Kyanite: 1 spectra
# Orthoclase: 1 spectra
# Pyrite: 1 spectra
#
# Rock 23 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Quartz	Quartz__R040031__Raman__780__0__unoriented__Raman_Data_Processed__26341.txt
# 1	Calcite	Calcite__R050127__Raman__532__0__unoriented__Raman_Data_Processed__27194.txt
# 2	Calcite	Calcite__R040070__Raman__785__0__unoriented__Raman_Data_Processed__15334.txt
# 3	Calcite	Calcite__R050128__Raman__514__0__unoriented__Raman_Data_Processed__5646.txt
# 4	Calcite	Calcite__R150075__Raman__780__0__unoriented__Raman_Data_Processed__38607.txt
# 5	Calcite	Calcite__R050307__Raman__532__0__unoriented__Raman_Data_Processed__28762.txt
# 6	Calcite	Calcite__R050130__Raman__532__0__unoriented__Raman_Data_Processed__27273.txt
# 7	Quartz	Quartz__R150091__Raman__780__0__unoriented__Raman_Data_Processed__39170.txt
# 8	Calcite	Calcite__R050307__Raman__780__0__unoriented__Raman_Data_Processed__28760.txt
# 9	Calcite	Calcite__R040070__Raman__785__0__unoriented__Raman_Data_Processed__15334.txt
# --------------------------------------------------
#
# Mineral Counts:
# Calcite: 8 spectra
# Quartz: 2 spectra
#
# Rock 24 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Dolomite	Dolomite__R050370__Raman__532__0__unoriented__Raman_Data_Processed__29622.txt
# 1	Calcite	Calcite__R050130__Raman__514__0__unoriented__Raman_Data_Processed__10130.txt
# 2	Calcite	Calcite__R050128__Raman__514__0__unoriented__Raman_Data_Processed__5646.txt
# 3	Epidote	Epidote__R110127__Raman__532__0__unoriented__Raman_Data_Processed__35622.txt
# 4	Rhodochrosite	Rhodochrosite__R050116__Raman__532__0__unoriented__Raman_Data_Processed__27092.txt
# 5	Calcite	Calcite__R040170__Raman__514__0__unoriented__Raman_Data_Processed__9653.txt
# 6	Calcite	Calcite__R050009__Raman__514__0__unoriented__Raman_Data_Processed__9847.txt
# 7	Calcite	Calcite__R050009__Raman__785__0__unoriented__Raman_Data_Processed__21025.txt
# 8	Calcite	Calcite__R050307__Raman__532__0__unoriented__Raman_Data_Processed__28762.txt
# 9	Calcite	Calcite__R040170__Raman__514__0__unoriented__Raman_Data_Processed__9653.txt
# --------------------------------------------------
#
# Mineral Counts:
# Calcite: 7 spectra
# Dolomite: 1 spectra
# Epidote: 1 spectra
# Rhodochrosite: 1 spectra
#
# Rock 25 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Calcite	Calcite__R150020__Raman__780__0__unoriented__Raman_Data_Processed__38861.txt
# 1	Calcite	Calcite__R150075__Raman__532__0__unoriented__Raman_Data_Processed__38605.txt
# 2	Calcite	Calcite__R040170__Raman__785__0__unoriented__Raman_Data_Processed__20888.txt
# 3	Calcite	Calcite__R040070__Raman__785__0__unoriented__Raman_Data_Processed__15334.txt
# 4	Calcite	Calcite__R050128__Raman__514__0__unoriented__Raman_Data_Processed__5646.txt
# 5	Calcite	Calcite__R150075__Raman__780__0__unoriented__Raman_Data_Processed__38607.txt
# 6	Calcite	Calcite__R050128__Raman__532__0__unoriented__Raman_Data_Processed__27265.txt
# 7	Calcite	Calcite__R040170__Raman__514__0__unoriented__Raman_Data_Processed__9653.txt
# 8	Calcite	Calcite__R050307__Raman__514__0__unoriented__Raman_Data_Processed__10750.txt
# 9	Calcite	Calcite__R050128__Raman__532__0__unoriented__Raman_Data_Processed__27265.txt
# --------------------------------------------------
#
# Mineral Counts:
# Calcite: 10 spectra
#
# Rock 26 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Quartz	Quartz__R150091__Raman__532__0__unoriented__Raman_Data_Processed__39166.txt
# 1	Calcite	Calcite__R050130__Raman__780__0__unoriented__Raman_Data_Processed__27275.txt
# 2	Quartz	Quartz__X080015__Raman__780__0__unoriented__Raman_Data_Processed__31560.txt
# 3	Albite	Albite__R070268__Raman__532__0__unoriented__Raman_Data_Processed__20224.txt
# 4	Calcite	Calcite__R050048__Raman__532__0__unoriented__Raman_Data_Processed__21180.txt
# 5	Pyrite	Pyrite__R100166__Raman__532__0__unoriented__Raman_Data_Processed__34671.txt
# 6	Quartz	Quartz__R060604__Raman__780__0__unoriented__Raman_Data_Processed__31951.txt
# 7	Calcite	Calcite__R150075__Raman__532__0__unoriented__Raman_Data_Processed__38605.txt
# 8	Calcite	Calcite__R050009__Raman__532__0__unoriented__Raman_Data_Processed__21027.txt
# 9	Calcite	Calcite__R050130__Raman__532__0__unoriented__Raman_Data_Processed__27273.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Calcite: 5 spectra
# Pyrite: 1 spectra
# Quartz: 3 spectra
#
# Rock 27 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Calcite	Calcite__R050307__Raman__514__0__unoriented__Raman_Data_Processed__10750.txt
# 1	Quartz	Quartz__R060604__Raman__532__0__unoriented__Raman_Data_Processed__31949.txt
# 2	Calcite	Calcite__R050009__Raman__532__0__unoriented__Raman_Data_Processed__21027.txt
# 3	Calcite	Calcite__R050128__Raman__532__0__unoriented__Raman_Data_Processed__27265.txt
# 4	Calcite	Calcite__R050009__Raman__532__0__unoriented__Raman_Data_Processed__21027.txt
# 5	Calcite	Calcite__R150020__Raman__780__0__unoriented__Raman_Data_Processed__38861.txt
# 6	Calcite	Calcite__R050127__Raman__532__0__unoriented__Raman_Data_Processed__27194.txt
# 7	Quartz	Quartz__R040031__Raman__514__0__unoriented__Raman_Data_Processed__9312.txt
# 8	Calcite	Calcite__R050307__Raman__780__0__unoriented__Raman_Data_Processed__28760.txt
# 9	Quartz	Quartz__R110104__Raman__780__0__unoriented__Raman_Data_Processed__35857.txt
# --------------------------------------------------
#
# Mineral Counts:
# Calcite: 7 spectra
# Quartz: 3 spectra
#
# Rock 28 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Sanidine	Sanidine__R060313__Raman__532__0__unoriented__Raman_Data_Processed__34073.txt
# 1	Quartz	Quartz__R040031__Raman__532__0__unoriented__Raman_Data_Processed__26343.txt
# 2	Sanidine	Sanidine__R060313__Raman__532__0__unoriented__Raman_Data_Processed__34073.txt
# 3	Calcite	Calcite__R050307__Raman__532__0__unoriented__Raman_Data_Processed__28762.txt
# 4	Calcite	Calcite__R050009__Raman__532__0__unoriented__Raman_Data_Processed__21027.txt
# 5	Sanidine	Sanidine__R060313__Raman__780__0__unoriented__Raman_Data_Processed__34075.txt
# 6	Calcite	Calcite__R050048__Raman__785__0__unoriented__Raman_Data_Processed__21182.txt
# 7	Calcite	Calcite__R050048__Raman__514__0__unoriented__Raman_Data_Processed__9918.txt
# 8	Calcite	Calcite__R050009__Raman__532__0__unoriented__Raman_Data_Processed__21027.txt
# 9	Calcite	Calcite__R050048__Raman__785__0__unoriented__Raman_Data_Processed__21182.txt
# --------------------------------------------------
#
# Mineral Counts:
# Calcite: 6 spectra
# Quartz: 1 spectra
# Sanidine: 3 spectra
#
# Rock 29 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Calcite	Calcite__R050130__Raman__780__0__unoriented__Raman_Data_Processed__27275.txt
# 1	Calcite	Calcite__R050307__Raman__514__0__unoriented__Raman_Data_Processed__10750.txt
# 2	Calcite	Calcite__R050307__Raman__532__0__unoriented__Raman_Data_Processed__28762.txt
# 3	Albite	Albite__R050402__Raman__780__0__unoriented__Raman_Data_Processed__30008.txt
# 4	Calcite	Calcite__R050130__Raman__780__0__unoriented__Raman_Data_Processed__27275.txt
# 5	Calcite	Calcite__R150075__Raman__532__0__unoriented__Raman_Data_Processed__38605.txt
# 6	Calcite	Calcite__R050307__Raman__532__0__unoriented__Raman_Data_Processed__28762.txt
# 7	Calcite	Calcite__R040170__Raman__785__0__unoriented__Raman_Data_Processed__20888.txt
# 8	Calcite	Calcite__R050128__Raman__532__0__unoriented__Raman_Data_Processed__27265.txt
# 9	Calcite	Calcite__R050128__Raman__532__0__unoriented__Raman_Data_Processed__27265.txt
# --------------------------------------------------
#
# Mineral Counts:
# Albite: 1 spectra
# Calcite: 9 spectra
#
# Rock 30 Composition:
# --------------------------------------------------
# Row	Mineral	Filename
# --------------------------------------------------
# 0	Calcite	Calcite__R050307__Raman__780__0__unoriented__Raman_Data_Processed__28760.txt
# 1	Calcite	Calcite__R050130__Raman__532__0__unoriented__Raman_Data_Processed__27273.txt
# 2	Calcite	Calcite__R050009__Raman__532__0__unoriented__Raman_Data_Processed__21027.txt
# 3	Calcite	Calcite__R050127__Raman__532__0__unoriented__Raman_Data_Processed__27194.txt
# 4	Calcite	Calcite__R050128__Raman__514__0__unoriented__Raman_Data_Processed__5646.txt
# 5	Calcite	Calcite__R050009__Raman__785__0__unoriented__Raman_Data_Processed__21025.txt
# 6	Calcite	Calcite__R050009__Raman__532__0__unoriented__Raman_Data_Processed__21027.txt
# 7	Calcite	Calcite__R040070__Raman__785__0__unoriented__Raman_Data_Processed__15334.txt
# 8	Calcite	Calcite__R050128__Raman__514__0__unoriented__Raman_Data_Processed__5646.txt
# 9	Calcite	Calcite__R050009__Raman__514__0__unoriented__Raman_Data_Processed__9847.txt
# --------------------------------------------------
#
# Mineral Counts:
# Calcite: 10 spectra
