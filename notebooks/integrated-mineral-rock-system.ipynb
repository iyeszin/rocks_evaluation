# %% [markdown]
# ## Hybrid classifier - baseline + expert system

# %%
import torch
import joblib
from pathlib import Path
import numpy as np
import pandas as pd
# from rocks_evaluation import SimpleCNN1D, UncertaintyAwareCNN1D, IntegratedRockClassifier, UncertaintyIntegratedRockClassifier, RockType, MineralGroups, save_analysis, plot_mineral_analysis
from rocks_evaluation import SimpleCNN1D, HierarchicalRockClassifier, save_analysis

# %%
# Load label encoder
label_encoder = joblib.load('../mineral_label_encoder.joblib')
print(label_encoder.classes_)
# Out:
# ['Albite' 'Almandine' 'Andalusite' 'Annite' 'Anorthite' 'Calcite'
#  'Dolomite' 'Epidote' 'Glaucophane' 'Jadeite' 'Kyanite' 'Muscovite'
#  'Omphacite' 'Orthoclase' 'Phlogopite' 'Pyrite' 'Pyrope' 'Quartz'
#  'Rhodochrosite' 'Rutile' 'Sanidine' 'Staurolite' 'Tourmaline']

# %%
# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

baseline_model = SimpleCNN1D()  
# uncertainty_model = UncertaintyAwareCNN1D()

# Model configuration and loading
best_repeat = 2
best_fold = 1
best_overall_accuracy = 0.9836
best_model_path = f'../weights/model_repeat{best_repeat}_fold{best_fold}_acc{best_overall_accuracy:.4f}.pth'

# For standard classification
# Initialize model and load weights
best_model = baseline_model.to(device)  # Make sure to import your model class
best_checkpoint = torch.load(best_model_path, weights_only=False)
best_model.load_state_dict(best_checkpoint['model_state_dict'])
best_model.eval()

# Load label encoder
label_encoder = joblib.load('../mineral_label_encoder.joblib')

# Initialize rock analyzer with HierarchicalRockClassifier instead
rock_analyzer = HierarchicalRockClassifier(
    model=best_model,
    label_encoder=label_encoder,
    device=device,
)

# %%
# Load and process data
base_path = Path("../validation_rocks")
results = []

for rock_num in range(1, 31):
    rock_analyzer.analysis_history = []  # Reset analysis history at start of each rock
    rock_analyzer.prediction_history = []  # Reset prediction history
    rock_analyzer.ground_truth_history = []  # Reset ground truth history

    print(f"\nProcessing Rock {rock_num}")
    rock_folder = f"rock_{rock_num:02d}"
    rock_path = base_path / rock_folder
    wavelengths = np.load(f"{rock_path}_wavelengths.npy")
    intensities = np.load(f"{rock_path}_intensities.npy")
    
    # Load true composition
    true_compositions = []
    composition_file = rock_path.with_name(f"{rock_path.stem}_composition.txt")
    with open(composition_file, 'r') as f:
        next(f)  # Skip header
        true_compositions = [line.strip().split('\t')[1] for line in f]
    
    final_result = None
    
    # Process spectra and collect results
    for i, spectrum in enumerate(intensities):
        spectrum_tensor = torch.from_numpy(spectrum).float()
        result = rock_analyzer.process_spectrum(spectrum_tensor, true_compositions[i])
        final_result = result
        
        # Print analysis if we have a full window
        if i >= 9:  # After 10 measurements
            print(f"\nAnalysis Results:")
            print(f"Classification: {result['rock_analysis']['classification']}")
            if 'weights' in result['rock_analysis']:
                print("Rock Type Weights:")
                for rock_type, weight in result['rock_analysis']['weights'].items():
                    print(f"- {rock_type.capitalize()}: {weight:.3f}")
    
    # Save results after all spectra are processed
    if final_result:
        weights = final_result['rock_analysis'].get('weights', {})
        # Get the highest weight as accuracy
        max_weight = max(weights.values()) if weights else 0.0
        
        results.append({
            'rock_num': rock_num,
            'classification': final_result['rock_analysis']['classification'],
            'accuracy': max_weight,  # Using highest weight as accuracy
            'weights': weights
        })
        
        # Update the analysis results before saving
        final_result['rock_analysis']['accuracy'] = max_weight
        
        # Save analysis results
        save_analysis(final_result, f'rock{rock_num}_analysis_results.txt')
        
        # Create visualization
        rock_analyzer.plot_analysis(rock_num, f'rock_analysis{rock_num}.png')

# Save final results with more detailed information
df = pd.DataFrame(results)
df.to_csv('rock_classifications.csv', index=False)

# Print summary statistics
print("\nSummary Statistics:")
print(f"Total rocks processed: {len(df)}")
print("\nClassification Distribution:")
print(df['classification'].value_counts())
print("\nAccuracy Statistics:")
print(f"Mean accuracy: {df['accuracy'].mean():.2%}")
print(f"Median accuracy: {df['accuracy'].median():.2%}")
# Out:
# Processing Rock 1
#
# DEBUG: Predictions received: ['Albite', 'Anorthite', 'Quartz', 'Quartz', 'Annite', 'Muscovite', 'Quartz', 'Albite', 'Annite', 'Orthoclase']
#
# DEBUG: Mineral counts:
# quartz: 3
# feldspars: 4
# micas: 3
# calcite: 0
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.30
# Feldspar ratio: 0.40
# Mica ratio: 0.30
# Calcite ratio: 0.00
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.200
# - Limestone: 0.000
#
# Processing Rock 2
#
# DEBUG: Predictions received: ['Albite', 'Quartz', 'Annite', 'Annite', 'Muscovite', 'Orthoclase', 'Sanidine', 'Quartz', 'Quartz', 'Anorthite']
#
# DEBUG: Mineral counts:
# quartz: 3
# feldspars: 3
# micas: 3
# calcite: 0
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.30
# Feldspar ratio: 0.30
# Mica ratio: 0.30
# Calcite ratio: 0.00
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.333
# - Limestone: 0.000
#
# Processing Rock 3
#
# DEBUG: Predictions received: ['Muscovite', 'Quartz', 'Quartz', 'Tourmaline', 'Orthoclase', 'Muscovite', 'Anorthite', 'Quartz', 'Annite', 'Quartz']
#
# DEBUG: Mineral counts:
# quartz: 4
# feldspars: 2
# micas: 3
# calcite: 0
# pyrite: 0
# rutile: 0
# tourmaline: 1
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.40
# Feldspar ratio: 0.20
# Mica ratio: 0.30
# Calcite ratio: 0.00
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.833
# - Limestone: 0.000
#
# Processing Rock 4
#
# DEBUG: Predictions received: ['Orthoclase', 'Muscovite', 'Annite', 'Orthoclase', 'Albite', 'Anorthite', 'Muscovite', 'Annite', 'Quartz', 'Phlogopite']
#
# DEBUG: Mineral counts:
# quartz: 1
# feldspars: 4
# micas: 5
# calcite: 0
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.10
# Feldspar ratio: 0.40
# Mica ratio: 0.50
# Calcite ratio: 0.00
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: False
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.500
# - Limestone: 0.000
#
# Processing Rock 5
#
# DEBUG: Predictions received: ['Annite', 'Phlogopite', 'Muscovite', 'Albite', 'Anorthite', 'Quartz', 'Annite', 'Muscovite', 'Muscovite', 'Muscovite']
#
# DEBUG: Mineral counts:
# quartz: 1
# feldspars: 2
# micas: 7
# calcite: 0
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.10
# Feldspar ratio: 0.20
# Mica ratio: 0.70
# Calcite ratio: 0.00
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: False
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: sandstone
# Rock Type Weights:
# - Granite: 0.000
# - Sandstone: 1.000
# - Limestone: 0.000
#
# Processing Rock 6
#
# DEBUG: Predictions received: ['Annite', 'Quartz', 'Quartz', 'Annite', 'Albite', 'Anorthite', 'Orthoclase', 'Albite', 'Annite', 'Muscovite']
#
# DEBUG: Mineral counts:
# quartz: 2
# feldspars: 4
# micas: 4
# calcite: 0
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.20
# Feldspar ratio: 0.40
# Mica ratio: 0.40
# Calcite ratio: 0.00
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.250
# - Limestone: 0.000
#
# Processing Rock 7
#
# DEBUG: Predictions received: ['Quartz', 'Annite', 'Muscovite', 'Quartz', 'Anorthite', 'Orthoclase', 'Quartz', 'Albite', 'Quartz', 'Annite']
#
# DEBUG: Mineral counts:
# quartz: 4
# feldspars: 3
# micas: 3
# calcite: 0
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.40
# Feldspar ratio: 0.30
# Mica ratio: 0.30
# Calcite ratio: 0.00
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.333
# - Limestone: 0.000
#
# Processing Rock 8
#
# DEBUG: Predictions received: ['Orthoclase', 'Muscovite', 'Anorthite', 'Albite', 'Muscovite', 'Phlogopite', 'Quartz', 'Quartz', 'Muscovite', 'Muscovite']
#
# DEBUG: Mineral counts:
# quartz: 2
# feldspars: 3
# micas: 5
# calcite: 0
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.20
# Feldspar ratio: 0.30
# Mica ratio: 0.50
# Calcite ratio: 0.00
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.500
# - Limestone: 0.000
#
# Processing Rock 9
#
# DEBUG: Predictions received: ['Anorthite', 'Quartz', 'Pyrite', 'Staurolite', 'Orthoclase', 'Phlogopite', 'Muscovite', 'Albite', 'Quartz', 'Annite']
#
# DEBUG: Mineral counts:
# quartz: 2
# feldspars: 3
# micas: 3
# calcite: 0
# pyrite: 1
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.20
# Feldspar ratio: 0.30
# Mica ratio: 0.30
# Calcite ratio: 0.00
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.333
# - Limestone: 0.000
#
# Processing Rock 10
#
# DEBUG: Predictions received: ['Staurolite', 'Annite', 'Quartz', 'Anorthite', 'Albite', 'Orthoclase', 'Muscovite', 'Staurolite', 'Quartz', 'Annite']
#
# DEBUG: Mineral counts:
# quartz: 2
# feldspars: 3
# micas: 3
# calcite: 0
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.20
# Feldspar ratio: 0.30
# Mica ratio: 0.30
# Calcite ratio: 0.00
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.333
# - Limestone: 0.000
#
# Processing Rock 11
#
# DEBUG: Predictions received: ['Quartz', 'Calcite', 'Sanidine', 'Albite', 'Anorthite', 'Pyrite', 'Annite', 'Phlogopite', 'Muscovite', 'Tourmaline']
#
# DEBUG: Mineral counts:
# quartz: 1
# feldspars: 2
# micas: 3
# calcite: 1
# pyrite: 1
# rutile: 0
# tourmaline: 1
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.10
# Feldspar ratio: 0.20
# Mica ratio: 0.30
# Calcite ratio: 0.10
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: False
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: sandstone
# Rock Type Weights:
# - Granite: 0.400
# - Sandstone: 1.000
# - Limestone: 0.000
#
# Processing Rock 12
#
# DEBUG: Predictions received: ['Albite', 'Orthoclase', 'Anorthite', 'Tourmaline', 'Rutile', 'Muscovite', 'Quartz', 'Calcite', 'Annite', 'Anorthite']
#
# DEBUG: Mineral counts:
# quartz: 1
# feldspars: 4
# micas: 2
# calcite: 1
# pyrite: 0
# rutile: 1
# tourmaline: 1
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.10
# Feldspar ratio: 0.40
# Mica ratio: 0.20
# Calcite ratio: 0.10
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: False
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.333
# - Limestone: 0.000
#
# Processing Rock 13
#
# DEBUG: Predictions received: ['Sanidine', 'Albite', 'Sanidine', 'Quartz', 'Calcite', 'Quartz', 'Albite', 'Anorthite', 'Muscovite', 'Annite']
#
# DEBUG: Mineral counts:
# quartz: 2
# feldspars: 3
# micas: 2
# calcite: 1
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.20
# Feldspar ratio: 0.30
# Mica ratio: 0.20
# Calcite ratio: 0.10
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.333
# - Limestone: 0.000
#
# Processing Rock 14
#
# DEBUG: Predictions received: ['Pyrite', 'Orthoclase', 'Quartz', 'Calcite', 'Quartz', 'Albite', 'Anorthite', 'Tourmaline', 'Rutile', 'Annite']
#
# DEBUG: Mineral counts:
# quartz: 2
# feldspars: 3
# micas: 1
# calcite: 1
# pyrite: 1
# rutile: 1
# tourmaline: 1
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.20
# Feldspar ratio: 0.30
# Mica ratio: 0.10
# Calcite ratio: 0.10
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: True
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.333
# - Limestone: 0.000
#
# Processing Rock 15
#
# DEBUG: Predictions received: ['Albite', 'Anorthite', 'Anorthite', 'Phlogopite', 'Muscovite', 'Annite', 'Quartz', 'Orthoclase', 'Quartz', 'Quartz']
#
# DEBUG: Mineral counts:
# quartz: 3
# feldspars: 4
# micas: 3
# calcite: 0
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.30
# Feldspar ratio: 0.40
# Mica ratio: 0.30
# Calcite ratio: 0.00
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.200
# - Limestone: 0.000
#
# Processing Rock 16
#
# DEBUG: Predictions received: ['Sanidine', 'Albite', 'Anorthite', 'Annite', 'Muscovite', 'Quartz', 'Quartz', 'Quartz', 'Tourmaline', 'Annite']
#
# DEBUG: Mineral counts:
# quartz: 3
# feldspars: 2
# micas: 3
# calcite: 0
# pyrite: 0
# rutile: 0
# tourmaline: 1
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.30
# Feldspar ratio: 0.20
# Mica ratio: 0.30
# Calcite ratio: 0.00
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.833
# - Limestone: 0.000
#
# Processing Rock 17
#
# DEBUG: Predictions received: ['Quartz', 'Anorthite', 'Sanidine', 'Orthoclase', 'Phlogopite', 'Staurolite', 'Quartz', 'Muscovite', 'Quartz', 'Annite']
#
# DEBUG: Mineral counts:
# quartz: 3
# feldspars: 2
# micas: 3
# calcite: 0
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.30
# Feldspar ratio: 0.20
# Mica ratio: 0.30
# Calcite ratio: 0.00
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.833
# - Limestone: 0.000
#
# Processing Rock 18
#
# DEBUG: Predictions received: ['Albite', 'Phlogopite', 'Orthoclase', 'Albite', 'Muscovite', 'Annite', 'Calcite', 'Quartz', 'Albite', 'Pyrite']
#
# DEBUG: Mineral counts:
# quartz: 1
# feldspars: 4
# micas: 3
# calcite: 1
# pyrite: 1
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.10
# Feldspar ratio: 0.40
# Mica ratio: 0.30
# Calcite ratio: 0.10
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: False
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.333
# - Limestone: 0.000
#
# Processing Rock 19
#
# DEBUG: Predictions received: ['Muscovite', 'Albite', 'Quartz', 'Quartz', 'Albite', 'Muscovite', 'Muscovite', 'Quartz', 'Calcite', 'Annite']
#
# DEBUG: Mineral counts:
# quartz: 3
# feldspars: 2
# micas: 4
# calcite: 1
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.30
# Feldspar ratio: 0.20
# Mica ratio: 0.40
# Calcite ratio: 0.10
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: sandstone
# Rock Type Weights:
# - Granite: 0.800
# - Sandstone: 1.000
# - Limestone: 0.000
#
# Processing Rock 20
#
# DEBUG: Predictions received: ['Quartz', 'Muscovite', 'Tourmaline', 'Quartz', 'Calcite', 'Albite', 'Tourmaline', 'Annite', 'Muscovite', 'Orthoclase']
#
# DEBUG: Mineral counts:
# quartz: 2
# feldspars: 2
# micas: 3
# calcite: 1
# pyrite: 0
# rutile: 0
# tourmaline: 2
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.20
# Feldspar ratio: 0.20
# Mica ratio: 0.30
# Calcite ratio: 0.10
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: False
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.833
# - Limestone: 0.000
#
# Processing Rock 21
#
# DEBUG: Predictions received: ['Calcite', 'Quartz', 'Dolomite', 'Calcite', 'Calcite', 'Anorthite', 'Albite', 'Calcite', 'Calcite', 'Dolomite']
#
# DEBUG: Mineral counts:
# quartz: 1
# feldspars: 2
# micas: 0
# calcite: 5
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.10
# Feldspar ratio: 0.20
# Mica ratio: 0.00
# Calcite ratio: 0.50
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: False
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: True
#
# Analysis Results:
# Classification: limestone
# Rock Type Weights:
# - Granite: 0.250
# - Sandstone: 0.375
# - Limestone: 1.000
#
# Processing Rock 22
#
# DEBUG: Predictions received: ['Anorthite', 'Calcite', 'Calcite', 'Albite', 'Orthoclase', 'Calcite', 'Calcite', 'Anorthite', 'Pyrite', 'Calcite']
#
# DEBUG: Mineral counts:
# quartz: 0
# feldspars: 4
# micas: 0
# calcite: 5
# pyrite: 1
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.00
# Feldspar ratio: 0.40
# Mica ratio: 0.00
# Calcite ratio: 0.50
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: False
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: True
#
# Analysis Results:
# Classification: limestone
# Rock Type Weights:
# - Granite: 0.750
# - Sandstone: 0.000
# - Limestone: 1.000
#
# Processing Rock 23
#
# DEBUG: Predictions received: ['Quartz', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Quartz', 'Calcite', 'Calcite']
#
# DEBUG: Mineral counts:
# quartz: 2
# feldspars: 0
# micas: 0
# calcite: 8
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.20
# Feldspar ratio: 0.00
# Mica ratio: 0.00
# Calcite ratio: 0.80
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: True
#
# Analysis Results:
# Classification: limestone
# Rock Type Weights:
# - Granite: 0.750
# - Sandstone: 0.000
# - Limestone: 1.000
#
# Processing Rock 24
#
# DEBUG: Predictions received: ['Dolomite', 'Calcite', 'Calcite', 'Staurolite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite']
#
# DEBUG: Mineral counts:
# quartz: 0
# feldspars: 0
# micas: 0
# calcite: 8
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.00
# Feldspar ratio: 0.00
# Mica ratio: 0.00
# Calcite ratio: 0.80
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: False
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: True
#
# Analysis Results:
# Classification: limestone
# Rock Type Weights:
# - Granite: 0.250
# - Sandstone: 0.000
# - Limestone: 1.000
#
# Processing Rock 25
#
# DEBUG: Predictions received: ['Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite', 'Calcite']
#
# DEBUG: Mineral counts:
# quartz: 0
# feldspars: 0
# micas: 0
# calcite: 10
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.00
# Feldspar ratio: 0.00
# Mica ratio: 0.00
# Calcite ratio: 1.00
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: False
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: True
#
# Analysis Results:
# Classification: limestone
# Rock Type Weights:
# - Granite: 0.200
# - Sandstone: 0.000
# - Limestone: 1.000
#
# Processing Rock 26
#
# DEBUG: Predictions received: ['Quartz', 'Calcite', 'Quartz', 'Albite', 'Calcite', 'Pyrite', 'Quartz', 'Calcite', 'Calcite', 'Dolomite']
#
# DEBUG: Mineral counts:
# quartz: 3
# feldspars: 1
# micas: 0
# calcite: 4
# pyrite: 1
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.30
# Feldspar ratio: 0.10
# Mica ratio: 0.00
# Calcite ratio: 0.40
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: True
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.500
# - Limestone: 0.000
#
# Processing Rock 27
#
# DEBUG: Predictions received: ['Calcite', 'Quartz', 'Dolomite', 'Calcite', 'Calcite', 'Calcite', 'Dolomite', 'Quartz', 'Dolomite', 'Quartz']
#
# DEBUG: Mineral counts:
# quartz: 3
# feldspars: 0
# micas: 0
# calcite: 4
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.30
# Feldspar ratio: 0.00
# Mica ratio: 0.00
# Calcite ratio: 0.40
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: True
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: True
#
# Analysis Results:
# Classification: granite
# Rock Type Weights:
# - Granite: 1.000
# - Sandstone: 0.000
# - Limestone: 0.000
#
# Processing Rock 28
#
# DEBUG: Predictions received: ['Sanidine', 'Quartz', 'Sanidine', 'Calcite', 'Dolomite', 'Sanidine', 'Calcite', 'Calcite', 'Calcite', 'Calcite']
#
# DEBUG: Mineral counts:
# quartz: 1
# feldspars: 0
# micas: 0
# calcite: 5
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.10
# Feldspar ratio: 0.00
# Mica ratio: 0.00
# Calcite ratio: 0.50
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: False
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: True
#
# Analysis Results:
# Classification: limestone
# Rock Type Weights:
# - Granite: 0.250
# - Sandstone: 0.000
# - Limestone: 1.000
#
# Processing Rock 29
#
# DEBUG: Predictions received: ['Calcite', 'Calcite', 'Dolomite', 'Albite', 'Dolomite', 'Calcite', 'Calcite', 'Calcite', 'Dolomite', 'Calcite']
#
# DEBUG: Mineral counts:
# quartz: 0
# feldspars: 1
# micas: 0
# calcite: 6
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.00
# Feldspar ratio: 0.10
# Mica ratio: 0.00
# Calcite ratio: 0.60
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: False
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: True
#
# Analysis Results:
# Classification: limestone
# Rock Type Weights:
# - Granite: 0.250
# - Sandstone: 0.375
# - Limestone: 1.000
#
# Processing Rock 30
#
# DEBUG: Predictions received: ['Calcite', 'Calcite', 'Dolomite', 'Calcite', 'Calcite', 'Calcite', 'Dolomite', 'Calcite', 'Calcite', 'Calcite']
#
# DEBUG: Mineral counts:
# quartz: 0
# feldspars: 0
# micas: 0
# calcite: 8
# pyrite: 0
# rutile: 0
# tourmaline: 0
#
# DEBUG: Mineral ratios:
# Quartz ratio: 0.00
# Feldspar ratio: 0.00
# Mica ratio: 0.00
# Calcite ratio: 0.80
#
# DEBUG: Checking granite criteria:
# 0.2 <= quartz_ratio <= 0.4: False
# 0.45 <= feldspar_ratio <= 0.8: False
# 0.0 <= mica_ratio <= 0.15: True
#
# Analysis Results:
# Classification: limestone
# Rock Type Weights:
# - Granite: 0.250
# - Sandstone: 0.000
# - Limestone: 1.000
#
# Summary Statistics:
# Total rocks processed: 30
#
# Classification Distribution:
# classification
# granite      19
# limestone     8
# sandstone     3
# Name: count, dtype: int64
#
# Accuracy Statistics:
# Mean accuracy: 100.00%
# Median accuracy: 100.00%

# %%
from analyze_results import analyze_results

analyze_results()
# Out:
# Confusion Matrix:
# [[5 0 0 0]
#  [2 5 0 0]
#  [6 3 0 2]
#  [6 0 0 1]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      granite       0.26      1.00      0.42         5
#    limestone       0.62      0.71      0.67         7
#        other       0.00      0.00      0.00        11
#    sandstone       0.33      0.14      0.20         7
#
#     accuracy                           0.37        30
#    macro avg       0.31      0.46      0.32        30
# weighted avg       0.27      0.37      0.27        30
# /home/iyeszin/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/iyeszin/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/iyeszin/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
